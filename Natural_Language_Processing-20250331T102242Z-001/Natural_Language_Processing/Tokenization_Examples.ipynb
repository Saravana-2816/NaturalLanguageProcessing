# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
corpus=""" Hello all, This is Saravana's from AIML.
   I had deep passion for web development and in deep learning too.
   I want enhace my career in ai.
"""

corpus
# Out:
# " Hello all, This is Saravana's from AIML.\n   I had deep passion for web development and in deep learning too.\n   I want enhace my career in ai.\n"

# %%
#tokenization
#sentence_tokenize
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
  print(sentence)
# Out:
#  Hello all, This is Saravana from AIML!!.
# I had deep passion for web development and in deep learning too.
# I want enhace my career in ai.

# %%
from nltk.tokenize import word_tokenize
words=word_tokenize(corpus)

# %%
type(words)
# Out:
# list

# %%
for sentence in documents:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'all', ',', 'This', 'is', 'Saravana', 'from', 'AIML', '!', '!', '.']
# ['I', 'had', 'deep', 'passion', 'for', 'web', 'development', 'and', 'in', 'deep', 'learning', 'too', '.']
# ['I', 'want', 'enhace', 'my', 'career', 'in', 'ai', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
words=wordpunct_tokenize(corpus)
words
# Out:
# ['Hello',
#  'all',
#  ',',
#  'This',
#  'is',
#  'Saravana',
#  "'",
#  's',
#  'from',
#  'AIML',
#  '!!.',
#  'I',
#  'had',
#  'deep',
#  'passion',
#  'for',
#  'web',
#  'development',
#  'and',
#  'in',
#  'deep',
#  'learning',
#  'too',
#  '.',
#  'I',
#  'want',
#  'enhace',
#  'my',
#  'career',
#  'in',
#  'ai',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'all',
#  ',',
#  'This',
#  'is',
#  'Saravana',
#  "'s",
#  'from',
#  'AIML.',
#  'I',
#  'had',
#  'deep',
#  'passion',
#  'for',
#  'web',
#  'development',
#  'and',
#  'in',
#  'deep',
#  'learning',
#  'too.',
#  'I',
#  'want',
#  'enhace',
#  'my',
#  'career',
#  'in',
#  'ai',
#  '.']
